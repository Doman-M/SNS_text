# %%
#セッションストレージにアップロードでファイルをアップロードする
# !apt install nkf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   nkf
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 133 kB of archives.
# After this operation, 362 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 nkf amd64 1:2.1.5-1build1 [133 kB]
# Fetched 133 kB in 1s (93.4 kB/s)
# Selecting previously unselected package nkf.
# (Reading database ... 122542 files and directories currently installed.)
# Preparing to unpack .../nkf_1%3a2.1.5-1build1_amd64.deb ...
# Unpacking nkf (1:2.1.5-1build1) ...
# Setting up nkf (1:2.1.5-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !nkf --gues sns_post.txt
# Out:
# unknown long option: --gues
# ソフト3つも買ってやったぜ
# わっはっは！！！
#
#
# おはようございます
# 今年の初夢は『魔法少女だったけど敵のカップル2人組に正体がバレたのでカップル2人組をゴルフに誘って楽しんでる間に撲○する』という夢でした。
# なんなんだこの夢………
#
#
# 足痛いのりんご飴食ったら治る
#
#
# 初詣でりんご飴食ったんで足指痛いの治りました卍卍卍卍卍
#
#
# 自分の投稿紐付ける機能ほしい…欲しくない？
#
#
# ネコオンザキャット
# #猫のいる生活
#
#
# 【悲報】
# ワガハイ、初夢の概念が間違ってたことが判明
# ってことは…
# 私の正式な初夢は『髪の毛てっぺんでくくったら髪の毛かき集めた部分の下がハゲてた夢』になるってコト！？
#
# 嫌すぎる……
#
#
# 今年はお絵描き上手になれるように頑張る。
# タブレット買ったしなぁ…頑張る
#
#
# あ〜〜〜〜〜
# 異世界行きたい………
# 現実に帰れる程度の距離デ……………
#
#
# あ゛ーーー！！！
# 線描くの苦手！！！！
# ドット絵に逃げちゃう！！！！！！
#
#
# 自分の描いたガッタガタの線画を綺麗に補正してくれるAI欲しい……
# 作るか………
#
#
# 明日奈良行く予定が友達の体調不良で延期になっちまった……
# まあ、私もまだ足指痛くて長距離歩けんからよかったっちゃよかったのかなぁ………
#
#
# ァ…………
# セーブするの忘れて3時間のレベル上げが無駄になっちった……………
# ァ゜……………(絶望)
#
#
# 友達に例の年賀状送ったけど、メッセージと差出人名書くの忘れてたから私からの年賀状ってのが誰一人も伝わってなかった
# アホス
#
#
# 最近不運過ぎんかい？？？
# もしかして初詣の大吉で今年の運使い果たした？？？？？
#
#
# 来年からは差出人名ちゃんとかきます
# うい
#
#
# あれーーーー？？？
# RPGってこんなに難しかったっけ？？？
# めっちゃ死ぬんやが？？？？
#
#
# 今日の夢おもしろかったなぁ……
# もう忘れかけてるけど
# 子猫のベンガル猫六匹拾って
# 脱走させちゃって、そしたら世界滅亡の危機的なことになって
# ...

# %%
text_list =[]
with open('sns_post.txt', encoding='UTF8') as f:
  text_list = f.readlines()

# %%
text_list[0:10]
# Out:
# ['ソフト3つも買ってやったぜ\n',
#  'わっはっは！！！\n',
#  '\n',
#  '\n',
#  'おはようございます\n',
#  '今年の初夢は『魔法少女だったけど敵のカップル2人組に正体がバレたのでカップル2人組をゴルフに誘って楽しんでる間に撲○する』という夢でした。\n',
#  'なんなんだこの夢………\n',
#  '\n',
#  '\n',
#  '足痛いのりんご飴食ったら治る\n']

# %%
# !pip install janome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 9.1 MB/s eta 0:00:00
# ...

# %%
from janome.tokenizer import Tokenizer

t = Tokenizer()
words = []
for text in text_list:
  tokens = t.tokenize(text)
  for token in tokens:
    pos = token.part_of_speech.split(',')[0]
    if pos == '名詞':
      words.append(token.surface)

text = ' '.join(words)

# %%
print(text[500:600])
# Out:
#  調節 峯沢 二 峯沢 RPG め 仕事 モードオン オフ キャラ 差 オラ 風邪 なん ん お前 人間 ポンペイ ポンペイ RPG バカ 私 明日 カラオケ 屋 switch パーチー ん 成人 式

# %%
# !apt -y install fonts-ipafont-gothic
# !pip install wordcloud
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 34 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 3s (2,696 kB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 122550 files and directories currently installed.)
# Preparing to unpack .../fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wordcloud = WordCloud(background_color="white", font_path=fpath, width=900, height=500).generate(text)
plt.figure(figsize=(15,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# import re
# new_text_list = []
# for text in text_list:
#   text = normalize_text(text)
#   new_text_list.append(text)

# text_list = new_text_list

# %%
# !pip install janome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from janome.tokenizer import Tokenizer

def wakachigaki(text_list):
  t = Tokenizer()
  words = []
  for text in text_list:
    tokens = t.tokenize(text)
    for token in tokens:
      pos = token.part_of_speech.split(',')[0]
      words.append(token.surface)

  text = ' '.join(words)
  return text

# %%
word_list = [w for w in wakachigaki(text_list).split()]
word_list[0:10]
# Out:
# ['ソフト', '3', 'つも', '買っ', 'て', 'やっ', 'た', 'ぜ', 'わっ', 'はっ']

# %%
test_text = ['私は猫が好きだ。君はマングースを愛している。私たちは相容れない。']
test_text = wakachigaki(test_text)
test_word_list = [w for w in test_text.split()]
test_word_list
# Out:
# ['私',
#  'は',
#  '猫',
#  'が',
#  '好き',
#  'だ',
#  '。',
#  '君',
#  'は',
#  'マングース',
#  'を',
#  '愛し',
#  'て',
#  'いる',
#  '。',
#  '私',
#  'たち',
#  'は',
#  '相容れない',
#  '。']
